# %%
from nuscenes.nuscenes import NuScenes
# import cv2 as cv
# import os, sys
# from scipy.spatial.transform import Rotation as rotation_angle_transformer
import numpy as np
import sys, os
sys.path.append('../src/')
from data.nuscene_loader import NuScenesLoader
from datetime import datetime 
import pickle
import pandas as pd
import cv2 as cv

# %%
# nusc = NuScenesLoader(dataset_name='v1.0-mini', dataroot='../../data/nuScenes', num_worker=4)

# %%
# scenes = nusc.get_all_scenes()
# start = datetime.now()
# data = nusc.get_samples_from_scene(scenes[0])
# print(datetime.now()-start)

# %%
data[0]
# Out:
# {'image': '/home/kiennt/KienNT/research/data/nuScenes/samples/CAM_FRONT/n015-2018-07-24-11-22-45+0800__CAM_FRONT__1532402927612460.jpg',
#  'calibration_matrix': {'sensor_R_quaternion': [0.4998015430569128,
#    -0.5030316162024876,
#    0.4997798114386805,
#    -0.49737083824542755],
#   'sensor_R': array([[-5.64133364e-03, -5.68014846e-03,  9.99967955e-01],
#          [-9.99983763e-01,  8.37115272e-04, -5.63666773e-03],
#          [-8.05071338e-04, -9.99983517e-01, -5.68477868e-03]]),
#   'sensor_t': [1.70079118954, 0.0159456324149, 1.51095763913],
#   'ego_R_quaternion': [0.5720063498929273,
#    -0.0021434844534272707,
#    0.011564094980151613,
#    -0.8201648693182716],
#   'ego_R': array([[ 0.99972335,  0.01651676,  0.01674549],
#          [-0.0214211 ,  0.34535001,  0.93822945],
#          [ 0.00971345, -0.9383286 ,  0.34560828]]),
#   'ego_t': [411.4199861830012, 1181.197175631848, 0.0],
#   'camera_intrinsic': [[1266.417203046554, 0.0, 816.2670197447984],
# ...

# %%
# train = pickle.load(open('../../data/nuScenes/pickle/train_val/train.pkl', 'rb'))
# for item in train:
#     item['image'] = item['image'].replace('/home/kiennt/KienNT/research/data/nuScenes/', '')
# pickle.dump(train, open('../../data/nuScenes/pickle/train_val/train.pkl', 'wb'))

# %%
# val = pickle.load(open('../../data/nuScenes/pickle/train_val/val.pkl', 'rb'))
# for item in train:
#     item['image'] = item['image'].replace('/home/kiennt/KienNT/research/data/nuScenes/', '')
# pickle.dump(train, open('../../data/nuScenes/pickle/train_val/val.pkl', 'wb'))
